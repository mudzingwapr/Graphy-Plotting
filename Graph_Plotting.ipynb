# %%
import matplotlib.pyplot as py
import pandas as pd
import matplotlib as mat

# %%
dataplot=pd.DataFrame({
    "Jan":[30,20,50,90],
    "Feb":[24,60,45,70],
    "Mar":[55,60,65,90],
    "April":[64,35,66,72]
}, index=["2000","2001","2002","2003"])
c=["red","green","white","black"]
dataplot.plot(kind="bar",color=c,linewidth=1,edgecolor="blue",figsize=(10,8))
mat.style.use("bmh")

# %%
List=
['it', 'was', 'the', 'best', 'of', 'times', 'it', 'was',
'the', 'worst', 'of', 'times', 'it', 'was', 'the', 'age',
'of', 'wisdom', 'it', 'was', 'the', 'age', 'of',
'foolishness']

Frequencies=
[4, 4, 4, 1, 4, 2, 4, 4, 4, 1, 4, 2, 4, 4, 4, 2, 4, 1, 4,
4, 4, 2, 4, 1]
py.plot(List,Frequencies)
# Out:
#   File "<ipython-input-14-1b761280a82c>", line 1
#     List=
#          ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as py
import pandas as pd
import numpy as np
import seaborn as sn

# %%
data =pd.read_csv("/home/mudzingwap/Documents/Doc.csv")
data
# Out:
#   Product_Name  Gender  Total  No_of_Buyers
# 0          F&B    Male     85            40
# 1          F&A  Female     70            60
# 2          E&A    Male     90            30
# 3          S&T    Male     40            50
# 4          F&B  Female     80            80
# 5          F&A    Male     88            75
# 6          E&A  Female     60            20
# 7          S&T  Female     50            33

# %%
#c=["red","green","white","black"]
py.figure(figsize=(10,8))
sn.barplot(x='Product_Name',y="No_of_Buyers",hue="Gender",data=data,linewidth=1,edgecolor="blue")
# Out:
# <AxesSubplot:xlabel='Product_Name', ylabel='No_of_Buyers'>
